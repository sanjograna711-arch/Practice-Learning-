# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjograna711-arch/Practice-Learning-/blob/main/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('/content/spotify.csv',index_col="Date", parse_dates = True)
df.head()
df.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
plt.figure(figsize=(14,6))
sn.lineplot(data = df)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize=(14,6))
sn.lineplot(data = df[['Shape of You', 'Despacito', 'Something Just Like This']])
# Out:
# <Axes: xlabel='Date'>

# %%
flight_path = ("/content/flight_delays.csv")
flight_data = pd.read_csv(flight_path,index_col= 'Month')

# %%
flight_data.columns
# Out:
# Index(['AA', 'AS', 'B6', 'DL', 'EV', 'F9', 'HA', 'MQ', 'NK', 'OO', 'UA', 'US',
#        'VX', 'WN'],
#       dtype='object')

# %%
plt.figure(figsize = (12,6))
sn.barplot(x = flight_data.index, y = flight_data["NK"],color = "#d95f5f")
# Out:
# <Axes: xlabel='Month', ylabel='NK'>

# %%
plt.figure(figsize = (10,6))

sn.heatmap(data=flight_data , annot = True)

plt.title("Flight delay heatmap")
plt.xlabel("Flight name")

plt.show()

# %%
insurance_data = pd.read_csv("/content/insurance.csv")
insurance_data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
plt.figure(figsize = (10,6))

sn.scatterplot(x = insurance_data.charges , y = insurance_data.bmi ,hue = insurance_data.age)


plt.show()
