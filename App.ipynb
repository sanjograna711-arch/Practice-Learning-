# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjograna711-arch/Practice-Learning-/blob/main/App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 76.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 80.5 MB/s eta 0:00:00

# %%
import streamlit as st

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(page_title="My Colab App", page_icon="🚀")

st.title("Hello from Google Colab!")
st.subheader("This app was built in a notebook and deployed via GitHub.")

name = st.text_input("What is your name?")
if name:
    st.write(f"Welcome to your first web app, {name}!")

st.balloons()
# Out:
# Overwriting app.py
